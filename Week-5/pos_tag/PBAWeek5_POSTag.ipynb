# %% [markdown]
# #POS (part-of-speech)
# WEEK 5 PBA/ Irmasari Hafidz
# Date: 24/ Sept/ 2024
#
# Part-of-speech (POS) tagging is the process of assigning a part-of-speech tag (Noun, Verb, Adjective...) to each word in an input text.
#
# Reference:
# * https://github.com/jalajthanaki/POS-tag-workshop/blob/master/Introduction_to_POS.ipynb
# * (ipynb) dari NLP Specialization on Coursera by deeplearning.ai
# * More advanced POS tagger with Transformers (BERT) https://github.com/soutsios/pos-tagger-bert/blob/master/pos_tagger_bert.ipynb

# %% [markdown]
# ##Data Scrapping
# Data scrapping menggunakan BeautifulSoup dari 3 link berita, search keyword: CNN BPJS TBC
#
# Link:
#
# * link 1: https://news.detik.com/berita/d-7477855/program-jkn-bantu-mega-keluarga-dapat-akses-layanan-kesehatan-gratis
#
# * link 2: https://www.cnnindonesia.com/ekonomi/20230828195349-92-991552/uang-bpjs-terkuras-rp10-t-imbas-penyakit-napas-termasuk-dampak-polusi
#
# * link 3: https://www.cnnindonesia.com/ekonomi/20210715134614-83-668092/jalan-kesembuhan-habudin-lawan-tbc-bersama-jkn-kis

# %%
# !pip install beautifulsoup4 requests
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
#      -------------------------------------- 107.7/107.7 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (2.32.5)
# Collecting soupsieve>=1.6.1
#   Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from requests) (2026.2.25)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.14.3 soupsieve-2.8.3
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Install necessary libraries (if not already installed)
# !pip install beautifulsoup4 requests pandas

import requests
from bs4 import BeautifulSoup
import pandas as pd

# List of URLs to scrape
urls = [
    "https://news.detik.com/berita/d-7477855/program-jkn-bantu-mega-keluarga-dapat-akses-layanan-kesehatan-gratis",
    "https://www.cnnindonesia.com/ekonomi/20230828195349-92-991552/uang-bpjs-terkuras-rp10-t-imbas-penyakit-napas-termasuk-dampak-polusi",
    "https://www.cnnindonesia.com/ekonomi/20210715134614-83-668092/jalan-kesembuhan-habudin-lawan-tbc-bersama-jkn-kis"
]

# Function to scrape content from a URL
def scrape_content(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')

            # Extract the title of the article
            title = soup.find('title').text

            # Extract the article's content
            paragraphs = soup.find_all('p')
            content = "\n".join([para.text for para in paragraphs])

            return {
                "url": url,
                "title": title,
                "content": content
            }
        else:
            return {
                "url": url,
                "title": None,
                "content": None,
                "error": f"Failed to fetch page, status code: {response.status_code}"
            }
    except Exception as e:
        return {
            "url": url,
            "title": None,
            "content": None,
            "error": str(e)
        }

# Scrape each URL and store the results in a list of dictionaries
data = []
for url in urls:
    result = scrape_content(url)
    data.append(result)

# Create a pandas DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Display the DataFrame
df.head()

# Save the DataFrame to a CSV file (optional)
df.to_csv('scraped_articles.csv', index=False)
# Out:
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: beautifulsoup4 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (4.14.3)
# Requirement already satisfied: requests in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (2.32.5)
# Requirement already satisfied: pandas in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (3.0.1)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from requests) (2026.2.25)
# Requirement already satisfied: numpy>=1.26.0 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\coding\pba\pba-tixid-sentimentanalysis\week-2\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## Data Definition
# Dataset adalah 3 link dengan kolom berisi: url, judul, konten.

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://news.detik.com/berita/d-7477855/progra...
# 1  https://www.cnnindonesia.com/ekonomi/202308281...
# 2  https://www.cnnindonesia.com/ekonomi/202107151...
#
#                                                title  \
# 0  Program JKN Bantu Mega & Keluarga Dapat Akses ...
# 1                                                NaN
# 2                                                NaN
#
#                                              content  \
# 0  Seorang peserta BPJS Kesehatan Mega Purwanti (...
# 1                                                NaN
# 2                                                NaN
#
#                                     error
# 0                                     NaN
# 1  Failed to fetch page, status code: 403
# 2  Failed to fetch page, status code: 403

# %%
# !pip install polyglot
# !pip install icu
# !pip install pycld2
# !pip install pyicu # Install the missing pyicu dependency
# !pip install morfessor
# Out:
# Collecting polyglot
#   Downloading polyglot-16.7.4.tar.gz (126 kB)
#      -------------------------------------- 126.3/126.3 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [10 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\Ratna Amalia\AppData\Local\Temp\pip-install-zcrya725\polyglot_f849bfa5c0d54e42ae9c98fb134bb899\setup.py", line 15, in <module>
#           readme = readme_file.read()
#                    ^^^^^^^^^^^^^^^^^^
#         File "C:\Python311\Lib\encodings\cp1252.py", line 23, in decode
#           return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 4941: character maps to <undefined>
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
#
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting icu
#   Downloading icu-0.0.1-py3-none-any.whl (49 kB)
#      -------------------------------------- 49.6/49.6 kB 148.4 kB/s eta 0:00:00
# Installing collected packages: icu
# Successfully installed icu-0.0.1
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pycld2
#   Downloading pycld2-0.42-cp311-cp311-win_amd64.whl (4.8 MB)
#      ---------------------------------------- 4.8/4.8 MB 7.4 MB/s eta 0:00:00
# Installing collected packages: pycld2
# Successfully installed pycld2-0.42
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: '#'
#
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting morfessor
#   Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Installing collected packages: morfessor
# Successfully installed morfessor-2.0.6
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import polyglot
from polyglot.text import Text, Word
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import polyglot
#       2 from polyglot.text import Text, Word
#
# ModuleNotFoundError: No module named 'polyglot'

# %%
# Importing packages and loading in the data set
import pandas as pd
from collections import defaultdict
import math
import numpy as np

# %%
# Assuming 'content' is the column with text
for index, row in df.iterrows():
    text = Text(row['content'])
    print("Language Detected: Code={}, Name={}\n".format(text.language.code, text.language.name))
# Out:
# Language Detected: Code=id, Name=Indonesian
#
# Language Detected: Code=id, Name=Indonesian
#
# Language Detected: Code=id, Name=Indonesian

# %% [markdown]
# ## POS tag contoh 1st row data
# Diambil dari df dari kolom [content] baris ke [1]

# %%
df_content1 = df['content'][1]
df_content1
# Out:
# 'Menteri Kesehatan Budi Gunadi Sadikin\xa0mengungkap\xa0penyakit pernapasan yang disebabkan oleh polusi udara membuat BPJS Kesehatan\xa0harus menghabiskan dana mencapai Rp10 triliun.\nHal ini disampaikan Budi\xa0usai meikuti rapat terbatas di Kantor Presiden soal\xa0polusi udara kawasan Jabodetabek pada Senin (28/8).\n"Kita laporkan bahwa ke-6 penyakit yang disebabkan karena gangguan pernapasan, ini beban BPJS-nya tahun lalu Rp10 triliun," ucap Budi.\n\r\nADVERTISEMENT\r\n\n\r\nSCROLL TO CONTINUE WITH CONTENT\r\n\n\nBudi\xa0merinci bahwa polusi udara bisa menyebabkan enam penyakit, termasuk pneumonia, infeksi saluran pernapasan akut (ISPA), asma, kanker paru, tuberkulosis (TBC) dan penyakit paru obstruktif kronik (PPOK).\nSepanjang 2023, Kementerian Kesehatan (Kemenkes) RI melihat adanya tren kenaikan beban BPJS untuk penyakit terkait pernapasan, terutama ISPA, asma dan pneumonia.\n"Yang top three-nya itu adalah infeksi paru atau pneumonia, ISPA kemudian asma. Ini totalnya sekitar Rp8 triliun dari Rp10 triliun yang dari enam penyakit," lanjut dia.\nDari sejumlah faktor yang bisa memicu penyakit pernapasan, Budi mengatakan bahwa temuan Kemenkes menunjukkan bahwa buruknya polusi udara adalah biang kerok paling dominan.\n\n\n"Penyebabnya banyak, yang paling dominan adalah polusi udara itu antara 24-34 persen dari 3 penyakit utama tadi, pneumonia, ISPA dan asma. Itu disebabkan oleh polusi udara," jelas Budi.\nTerkait ancaman kesehatan ini, Budi mengimbau masyarakat DKI Jakarta dan sekitarnya untuk tertib mengenakan masker saat beraktivitas di luar ruangan.\nDia menyarankan masyarakat menggunakan masker standar medis jenis KF94 dan KN95 yang memiliki kekuatan menahan partikel kecil untuk masuk ke paru-paru.\n[Gambas:Video CNN]\n'

# %%
df_content1_pos = Text(df_content1)
df_content1_pos.words
# Out:
# WordList(['Menteri', 'Kesehatan', 'Budi', 'Gunadi', 'Sadikin', 'mengungkap', 'penyakit', 'pernapasan', 'yang', 'disebabkan', 'oleh', 'polusi', 'udara', 'membuat', 'BPJS', 'Kesehatan', 'harus', 'menghabiskan', 'dana', 'mencapai', 'Rp10', 'triliun', '.', 'Hal', 'ini', 'disampaikan', 'Budi', 'usai', 'meikuti', 'rapat', 'terbatas', 'di', 'Kantor', 'Presiden', 'soal', 'polusi', 'udara', 'kawasan', 'Jabodetabek', 'pada', 'Senin', '(', '28', '/', '8', ')', '.', '"', 'Kita', 'laporkan', 'bahwa', 'ke', '-', '6', 'penyakit', 'yang', 'disebabkan', 'karena', 'gangguan', 'pernapasan', ',', 'ini', 'beban', 'BPJS', '-', 'nya', 'tahun', 'lalu', 'Rp10', 'triliun', ',', '"', 'ucap', 'Budi', '.', 'ADVERTISEMENT', 'SCROLL', 'TO', 'CONTINUE', 'WITH', 'CONTENT', 'Budi', 'merinci', 'bahwa', 'polusi', 'udara', 'bisa', 'menyebabkan', 'enam', 'penyakit', ',', 'termasuk', 'pneumonia', ',', 'infeksi', 'saluran', 'pernapasan', 'akut', '(', 'ISPA', ')', ',', 'asma', ',', 'kanker', 'paru', ',', 'tuberkulosis', '(', 'TBC', ')', 'dan', 'penyakit', 'paru', 'obstruktif', 'kronik', '(', 'PPOK', ')', '.', 'Sepanjang', '2023', ',', 'Kementerian', 'Kesehatan', '(', 'Kemenkes', ')', 'RI', 'melihat', 'adanya', 'tren', 'kenaikan', 'beban', 'BPJS', 'untuk', 'penyakit', 'terkait', 'pernapasan', ',', 'terutama', 'ISPA', ',', 'asma', 'dan', 'pneumonia', '.', '"', 'Yang', 'top', 'three', '-', 'nya', 'itu', 'adalah', 'infeksi', 'paru', 'atau', 'pneumonia', ',', 'ISPA', 'kemudian', 'asma', '.', 'Ini', 'totalnya', 'sekitar', 'Rp8', 'triliun', 'dari', 'Rp10', 'triliun', 'yang', 'dari', 'enam', 'penyakit', ',', '"', 'lanjut', 'dia', '.', 'Dari', 'sejumlah', 'faktor', 'yang', 'bisa', 'memicu', 'penyakit', 'pernapasan', ',', 'Budi', 'mengatakan', 'bahwa', 'temuan', 'Kemenkes', 'menunjukkan', 'bahwa', 'buruknya', 'polusi', 'udara', 'adalah', 'biang', 'kerok', 'paling', 'dominan', '.', '"', 'Penyebabnya', 'banyak', ',', 'yang', 'paling', 'dominan', 'adalah', 'polusi', 'udara', 'itu', 'antara', '24', '-', '34', 'persen', 'dari', '3', 'penyakit', 'utama', 'tadi', ',', 'pneumonia', ',', 'ISPA', 'dan', 'asma', '.', 'Itu', 'disebabkan', 'oleh', 'polusi', 'udara', ',', '"', 'jelas', 'Budi', '.', 'Terkait', 'ancaman', 'kesehatan', 'ini', ',', 'Budi', 'mengimbau', 'masyarakat', 'DKI', 'Jakarta', 'dan', 'sekitarnya', 'untuk', 'tertib', 'mengenakan', 'masker', 'saat', 'beraktivitas', 'di', 'luar', 'ruangan', '.', 'Dia', 'menyarankan', 'masyarakat', 'menggunakan', 'masker', 'standar', 'medis', 'jenis', 'KF94', 'dan', 'KN95', 'yang', 'memiliki', 'kekuatan', 'menahan', 'partikel', 'kecil', 'untuk', 'masuk', 'ke', 'paru', '-', 'paru', '.', '[', 'Gambas:Video', 'CNN', ']'])

# %%
# !pip install polyglot
# !polyglot download embeddings2.id
# !polyglot download pos2.id
# Out:
# Requirement already satisfied: polyglot in /usr/local/lib/python3.10/dist-packages (16.7.4)
# [polyglot_data] Downloading package embeddings2.id to
# [polyglot_data]     /root/polyglot_data...
# [polyglot_data]   Package embeddings2.id is already up-to-date!
# [polyglot_data] Downloading package pos2.id to /root/polyglot_data...

# %%
df_content1_pos = Text(df_content1)

print("{:<16}{}".format("Word", "POS Tag")+"\n"+"-"*30)
for word, tag in df_content1_pos.pos_tags: # Changed 'text' to 'df_content1_pos'
    print(u"{:<16}{:>2}".format(word, tag))
# Out:
# Word            POS Tag
# ------------------------------
# Menteri         PROPN
# Kesehatan       PROPN
# Budi            PROPN
# Gunadi          PROPN
# Sadikin         PROPN
# mengungkap      VERB
# penyakit        NOUN
# pernapasan      NOUN
# yang            PRON
# disebabkan      VERB
# oleh            ADP
# polusi          NOUN
# udara           NOUN
# membuat         VERB
# BPJS            PROPN
# Kesehatan       PROPN
# harus           ADV
# menghabiskan    VERB
# dana            NOUN
# mencapai        VERB
# Rp10            NUM
# triliun         NOUN
# .               PUNCT
# Hal             NOUN
# ini             DET
# disampaikan     VERB
# Budi            PROPN
# usai            VERB
# meikuti         NOUN
# rapat           NOUN
# terbatas        VERB
# di              ADP
# Kantor          PROPN
# Presiden        PROPN
# soal            NOUN
# polusi          NOUN
# udara           NOUN
# kawasan         NOUN
# Jabodetabek     PROPN
# pada            ADP
# Senin           PROPN
# (               PUNCT
# 28              NUM
# /               PUNCT
# 8               NUM
# )               PUNCT
# .               PUNCT
# "               PUNCT
# Kita            PROPN
# laporkan        VERB
# bahwa           CONJ
# ke              ADP
# -               PUNCT
# 6               NUM
# penyakit        NOUN
# yang            PRON
# disebabkan      VERB
# karena          CONJ
# gangguan        NOUN
# pernapasan      NOUN
# ,               PUNCT
# ini             DET
# beban           NOUN
# BPJS            NOUN
# -               PUNCT
# nya             PRON
# tahun           NOUN
# lalu            ADJ
# Rp10            NUM
# triliun         NOUN
# ,               PUNCT
# "               PUNCT
# ucap            NOUN
# Budi            PROPN
# .               PROPN
# ADVERTISEMENT   NUM
# SCROLL          NOUN
# TO              NOUN
# CONTINUE        NOUN
# WITH            NOUN
# CONTENT         PROPN
# Budi            PROPN
# merinci         VERB
# bahwa           CONJ
# polusi          NOUN
# udara           NOUN
# bisa            ADV
# menyebabkan     VERB
# enam            NUM
# penyakit        NOUN
# ,               PUNCT
# termasuk        VERB
# pneumonia       NOUN
# ,               PUNCT
# infeksi         NOUN
# saluran         NOUN
# pernapasan      NOUN
# akut            ADJ
# (               PUNCT
# ISPA            NOUN
# )               PUNCT
# ,               PUNCT
# asma            NOUN
# ,               PUNCT
# kanker          NOUN
# paru            NOUN
# ,               PUNCT
# tuberkulosis    NOUN
# (               PUNCT
# TBC             NOUN
# )               PUNCT
# dan             CONJ
# penyakit        NOUN
# paru            NOUN
# obstruktif      NUM
# kronik          ADJ
# (               PUNCT
# PPOK            NUM
# )               PUNCT
# .               PUNCT
# Sepanjang       ADP
# 2023            NUM
# ,               PUNCT
# Kementerian     PROPN
# Kesehatan       PROPN
# (               PUNCT
# Kemenkes        PROPN
# )               PUNCT
# RI              PROPN
# melihat         VERB
# adanya          NOUN
# tren            NOUN
# kenaikan        NOUN
# beban           NOUN
# BPJS            NOUN
# untuk           ADP
# penyakit        NOUN
# terkait         VERB
# pernapasan      NOUN
# ,               PUNCT
# terutama        ADV
# ISPA            NOUN
# ,               PUNCT
# asma            NOUN
# dan             CONJ
# pneumonia       NOUN
# .               PUNCT
# "               PUNCT
# Yang            PRON
# top             PROPN
# three           NOUN
# -               PUNCT
# nya             PRON
# itu             DET
# adalah          VERB
# infeksi         NOUN
# paru            NOUN
# atau            CONJ
# pneumonia       NOUN
# ,               PUNCT
# ISPA            NOUN
# kemudian        ADV
# asma            NOUN
# .               PUNCT
# Ini             DET
# totalnya        NOUN
# sekitar         ADP
# Rp8             NUM
# triliun         NOUN
# dari            ADP
# Rp10            NUM
# triliun         NOUN
# yang            PRON
# dari            ADP
# enam            NUM
# penyakit        NOUN
# ,               PUNCT
# "               PUNCT
# lanjut          ADJ
# dia             PRON
# .               PUNCT
# Dari            ADP
# sejumlah        DET
# faktor          NOUN
# yang            PRON
# bisa            ADV
# memicu          VERB
# penyakit        NOUN
# pernapasan      NOUN
# ,               PUNCT
# Budi            PROPN
# mengatakan      VERB
# bahwa           CONJ
# temuan          NOUN
# Kemenkes        PROPN
# menunjukkan     VERB
# bahwa           CONJ
# buruknya        NOUN
# polusi          NOUN
# udara           NOUN
# adalah          VERB
# biang           NOUN
# kerok           PROPN
# paling          ADV
# dominan         NOUN
# .               PUNCT
# "               PUNCT
# Penyebabnya     NOUN
# banyak          ADV
# ,               PUNCT
# yang            PRON
# paling          ADV
# dominan         ADJ
# adalah          VERB
# polusi          NOUN
# udara           NOUN
# itu             DET
# antara          ADP
# 24              NUM
# -               PUNCT
# 34              NUM
# persen          NOUN
# dari            ADP
# 3               NUM
# penyakit        NOUN
# utama           ADJ
# tadi            NOUN
# ,               PUNCT
# pneumonia       NOUN
# ,               PUNCT
# ISPA            NOUN
# dan             CONJ
# asma            NOUN
# .               PROPN
# Itu             DET
# disebabkan      VERB
# oleh            ADP
# polusi          NOUN
# udara           NOUN
# ,               PUNCT
# "               PUNCT
# jelas           ADJ
# Budi            PROPN
# .               PROPN
# Terkait         NOUN
# ancaman         NOUN
# kesehatan       NOUN
# ini             DET
# ,               PUNCT
# Budi            PROPN
# mengimbau       VERB
# masyarakat      NOUN
# DKI             PROPN
# Jakarta         PROPN
# dan             CONJ
# sekitarnya      NOUN
# untuk           ADP
# tertib          NOUN
# mengenakan      VERB
# masker          NOUN
# saat            CONJ
# beraktivitas    VERB
# di              ADP
# luar            NOUN
# ruangan         NOUN
# .               PUNCT
# Dia             PRON
# menyarankan     VERB
# masyarakat      NOUN
# menggunakan     VERB
# masker          NOUN
# standar         NOUN
# medis           NOUN
# jenis           NOUN
# KF94            NUM
# dan             CONJ
# KN95            PROPN
# yang            PRON
# memiliki        VERB
# kekuatan        NOUN
# menahan         VERB
# partikel        NOUN
# kecil           ADJ
# untuk           ADP
# masuk           VERB
# ke              ADP
# paru            NOUN
# -               PUNCT
# paru            NOUN
# .               PUNCT
# [               PUNCT
# Gambas:Video    NUM
# CNN             PROPN
# ]               PUNCT

# %% [markdown]
# ## Latihan 1
# Kerjakan POS tag untuk baris ke-2 dan ke-3.

# %%
import numpy as np
import pandas as pd

# %%
df_content1_pos
# Out:
# Text("Menteri Kesehatan Budi Gunadi Sadikin mengungkap penyakit pernapasan yang disebabkan oleh polusi udara membuat BPJS Kesehatan harus menghabiskan dana mencapai Rp10 triliun.
# Hal ini disampaikan Budi usai meikuti rapat terbatas di Kantor Presiden soal polusi udara kawasan Jabodetabek pada Senin (28/8).
# "Kita laporkan bahwa ke-6 penyakit yang disebabkan karena gangguan pernapasan, ini beban BPJS-nya tahun lalu Rp10 triliun," ucap Budi.
#
# ADVERTISEMENT
#
#
# SCROLL TO CONTINUE WITH CONTENT
#
#
# Budi mer...abnya banyak, yang paling dominan adalah polusi udara itu antara 24-34 persen dari 3 penyakit utama tadi, pneumonia, ISPA dan asma. Itu disebabkan oleh polusi udara," jelas Budi.
# Terkait ancaman kesehatan ini, Budi mengimbau masyarakat DKI Jakarta dan sekitarnya untuk tertib mengenakan masker saat beraktivitas di luar ruangan.
# Dia menyarankan masyarakat menggunakan masker standar medis jenis KF94 dan KN95 yang memiliki kekuatan menahan partikel kecil untuk masuk ke paru-paru.
# [Gambas:Video CNN]
# ")

# %%
import pandas as pd

# Assuming df_content1_pos is the object containing the tagged words and POS tags.
# Example structure:
# df_content1_pos.pos_tags should return a list of (word, pos_tag) tuples.

# Create a list of dictionaries to store each word and its POS tag
word_pos_list = [{"Word": word, "POS Tag": tag} for word, tag in df_content1_pos.pos_tags]

# Convert the list of dictionaries to a pandas DataFrame
df_word_pos = pd.DataFrame(word_pos_list)

# Display the DataFrame
print(df_word_pos)

# Optionally, save the DataFrame to a CSV file
df_word_pos.to_csv("word_pos_tags.csv", index=False)
# Out:
#              Word POS Tag
# 0         Menteri   PROPN
# 1       Kesehatan   PROPN
# 2            Budi   PROPN
# 3          Gunadi   PROPN
# 4         Sadikin   PROPN
# ..            ...     ...
# 289             .   PUNCT
# 290             [   PUNCT
# 291  Gambas:Video     NUM
# 292           CNN   PROPN
# 293             ]   PUNCT
#
# [294 rows x 2 columns]

# %%
import pandas as pd
from collections import Counter

# Assuming df_content1_pos is the object containing the tagged words and POS tags.
# Example structure: df_content1_pos.pos_tags should return a list of (word, pos_tag) tuples.

# Create a list of dictionaries to store each word and its POS tag
word_pos_list = [{"Word": word, "POS Tag": tag} for word, tag in df_content1_pos.pos_tags]

# Convert the list of dictionaries to a pandas DataFrame
df_word_pos = pd.DataFrame(word_pos_list)

# Count the occurrences of each POS tag
tag_counts = df_word_pos['POS Tag'].value_counts()

# Get the number of unique words for each POS tag
unique_tokens_per_tag = df_word_pos.groupby('POS Tag')['Word'].nunique()

# Combine the counts and unique tokens into a summary DataFrame
summary_df = pd.DataFrame({
    'Tag': tag_counts.index,
    'Count': tag_counts.values,
    'Unique Tokens': unique_tokens_per_tag
}).reset_index(drop=True)

# Sort by count in descending order
summary_df = summary_df.sort_values(by='Count', ascending=False)

# Display the summary DataFrame
print(summary_df)

# Optionally, save the summary DataFrame to a CSV file
summary_df.to_csv("pos_tags_summary.csv", index=False)
# Out:
#       Tag  Count  Unique Tokens
# 0    NOUN     98              8
# 1   PUNCT     51             10
# 2   PROPN     33              6
# 3    VERB     30              5
# 4     NUM     18              5
# 5     ADP     17             56
# 6    CONJ     12             15
# 7    PRON     11              5
# 8     ADV      8             22
# 9     DET      8              9
# 10    ADJ      8             26

# %%
# Calculate the sum of the 'Count' column
total_count = summary_df['Count'].sum()

# Display the result
print("Total Count:", total_count)
# Out:
# Total Count: 294
